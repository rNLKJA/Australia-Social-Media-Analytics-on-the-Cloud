# %%
import pandas as pd
import numpy as np
from pathlib import Path
import re
import pickle

# %%
sal_json_path = Path('../data/sal.json')

# %%
# this code is adapted from https://github.com/rNLKJA/Unimelb-Master-2023-COMP90024-Assignment-1/blob/main/main.py
# changes are required due to no need for polars dataframe
# remove logger dependencies
def split_location_into_ngrams(location):
    words = location.split(" ")
    if len(words) > 2:
        return [" ".join(x) for x in zip(words, words[1:])]
    return None

def sal_processor(path: Path) -> pd.DataFrame:
    """
    Process sal.json file by removing irrelevant attributes,
    case 0: remove any gcc containing char r (r represents rural)
    case 1: remove all brackets
    case 2: remove all " - "
    case 3: remove all "\."
    Then store the final result into a csv file.

    path (Path): root directory
    """
    # load sal.json file & reset index
    df = pd.read_json(path, orient="index")
    df = df.reset_index().rename(columns={"index": "location"})

    df.drop(["ste"], axis=1, inplace=True)

    # case1: replace all brackets with an empty string
    # logger.info("Substitute brackets in location")
    df.location = df.agg(lambda x: re.sub(r"[()]", "", x.location), axis=1)

    # case2: replace " - " with " "
    # logger.info("Substitude string ' - ' with ' '")
    df.location = df.agg(lambda x: re.sub(" - ", " ", x.location), axis=1)

    # case3: replace "\." with ""
    # logger.info("Substitude \. with an empty string")
    df.location = df.agg(lambda x: re.sub("\.", "", x.location), axis=1)
    df['real_loc'] = df.location
        
    # case 4: consider ngram like locations
    # generate a new dataframe and concate to the original one
    df1 = df.copy()

    df1["location"] = df1.location.apply(lambda x: split_location_into_ngrams(x))

    df1 = df1.dropna()[["location", "gcc", 'sal', 'real_loc']].explode("location")

    # concat the final result
    res_df = pd.concat([df, df1], ignore_index=True, axis=0)

    return res_df

# %%
sal_df = sal_processor(sal_json_path)
sal_df.dropna()
# Out:
#              location    gcc    sal              real_loc
# 0          abbotsbury  1gsyd  10002            abbotsbury
# 1      abbotsford nsw  1gsyd  10003        abbotsford nsw
# 2      acacia gardens  1gsyd  10014        acacia gardens
# 3         agnes banks  1gsyd  10021           agnes banks
# 4               airds  1gsyd  10022                 airds
# ...               ...    ...    ...                   ...
# 17647       creek act  8acte  80013  rendezvous creek act
# 17648    weston creek  8acte  80016      weston creek act
# 17649       creek act  8acte  80016      weston creek act
# 17650        red hill  8acte  80112          red hill act
# 17651        hill act  8acte  80112          red hill act
#
# [17652 rows x 4 columns]

# %%
sal_df.to_pickle(sal_json_path.resolve().parent / 'sal.pickle')
sal_df.to_pickle(sal_json_path.resolve().parent / 'sal.processed.json')

# %%
sal_dict = dict(zip(sal_df["location"].to_list(), sal_df["sal"].to_list()))
sal_dict
# Out:
# {'abbotsbury': 10002,
#  'abbotsford nsw': 10003,
#  'acacia gardens': 10014,
#  'agnes banks': 10021,
#  'airds': 10022,
#  'alexandria': 10030,
#  'alfords point': 10031,
#  'alison central coast nsw': 10034,
#  'allambie heights': 10036,
#  'allawah': 10038,
#  'ambarvale': 10049,
#  'angus': 10060,
#  'annandale nsw': 10062,
#  'annangrove': 10063,
#  'appin nsw': 10064,
#  'arcadia nsw': 10073,
#  'arncliffe': 10087,
#  'arndell park': 10088,
#  'artarmon': 10091,
#  'ashbury': 10094,
#  'ashcroft': 10098,
#  'ashfield nsw': 10099,
#  'asquith': 10104,
#  'auburn nsw': 10107,
#  'austral': 10110,
#  'avalon beach': 10112,
#  'avoca beach': 10115,
#  'badgerys creek': 10133,
#  'balgowlah': 10154,
#  'balgowlah heights': 10155,
#  'balmain': 10165,
#  'balmain east': 10166,
#  'bangor nsw': 10178,
#  'banksia': 10179,
#  'banksmeadow': 10180,
#  'bankstown': 10181,
#  'bankstown aerodrome': 10182,
#  'bar point': 10189,
#  'barangaroo': 10192,
#  'barden ridge': 10194,
#  'bardia': 10195,
#  'bardwell park': 10196,
#  'bardwell valley': 10197,
#  'bargo': 10199,
#  'bass hill': 10224,
#  'bateau bay': 10227,
#  'baulkham hills': 10233,
#  'bayview nsw': 10237,
#  'beacon hill': 10238,
#  'beaconsfield nsw': 10239,
#  'beaumont hills': 10243,
#  'beecroft': 10249,
#  'belfield': 10257,
#  'belimbla park': 10261,
#  'bella vista': 10263,
#  'bellevue hill': 10271,
#  'belmore': 10279,
#  'belrose': 10283,
#  'bensville': 10297,
#  'berala': 10299,
#  'berambing': 10300,
#  'berkeley vale': 10304,
#  'berkshire park': 10305,
#  'berowra': 10308,
#  'berowra heights': 10309,
#  'berowra waters': 10310,
#  'berrilee': 10318,
#  'beverley park': 10329,
#  'beverly hills': 10330,
#  'bexley': 10333,
#  'bexley north': 10334,
#  'bidwill nsw': 10339,
#  'bilgola beach': 10349,
#  'bilgola plateau': 10350,
#  'bilpin': 10357,
#  'birchgrove': 10373,
#  'birrong': 10378,
#  'blackett': 10391,
#  'blackheath': 10392,
#  'blacktown': 10396,
#  'blackwall nsw': 10398,
#  'blair athol nsw': 10399,
#  'blairmount': 10400,
#  'blakehurst': 10402,
#  'blaxland nsw': 10406,
#  'blaxlands ridge': 10408,
#  'bligh park': 10410,
#  'blue bay': 10413,
#  'blue haven': 10414,
#  'blue mountains national park': 10416,
#  'bondi': 10462,
#  'bondi beach': 10463,
#  'bondi junction': 10465,
#  'bonnet bay': 10467,
#  'bonnyrigg': 10469,
#  'bonnyrigg heights': 10470,
#  'booker bay': 10475,
#  'bossley park': 10513,
#  'botany': 10515,
#  'bouddi': 10518,
#  'bow bowing': 10524,
#  'bowen mountain': 10526,
#  'box head': 10536,
#  'box hill nsw': 10537,
#  'bradbury nsw': 10540,
#  'breakfast point': 10554,
#  'brighton-le-sands': 10566,
#  'bringelly': 10572,
#  'bronte': 10591,
#  'brooklyn nsw': 10596,
#  'brookvale': 10598,
#  'brownlow hill': 10606,
#  'budgewoi': 10639,
#  'budgewoi peninsula': 10640,
#  'buff point': 10642,
#  'bullaburra': 10653,
#  'bundeena': 10669,
#  'bungarribee': 10679,
#  'burraneer': 10702,
#  'burwood nsw': 10716,
#  'burwood heights': 10717,
#  'busby': 10718,
#  'bushells ridge': 10720,
#  'buxton nsw': 10724,
#  'cabarita nsw': 10734,
#  'cabramatta': 10738,
#  'cabramatta west': 10739,
#  'caddens': 10741,
#  'calga': 10751,
#  'cambridge gardens': 10766,
#  'cambridge park': 10767,
#  'camden': 10769,
#  'camden park nsw': 10771,
#  'camden south': 10772,
#  'camellia': 10773,
#  'cammeray': 10777,
#  'campbelltown nsw': 12390,
#  'camperdown nsw': 10780,
#  'campsie': 10781,
#  'canada bay': 10784,
#  'canley heights': 10790,
#  'canley vale': 10791,
#  'canoelands': 10793,
#  'canterbury nsw': 10796,
#  'canton beach': 10797,
#  'caringbah': 10814,
#  'caringbah south': 10815,
#  'carlingford': 10817,
#  'carlton nsw': 10818,
#  'carnes hill': 10819,
#  'carramar nsw': 10825,
#  'carss park': 10836,
#  'cartwright': 10837,
#  'castle cove': 10844,
#  'castle hill nsw': 10846,
#  'castlecrag': 10848,
#  'castlereagh': 10849,
#  'casula': 10851,
#  'catherine field': 10855,
#  'cattai': 10858,
#  'cawdor nsw': 10862,
#  'cecil hills': 10864,
#  'cecil park': 10865,
#  'cedar brush creek': 10866,
#  'centennial park nsw': 10872,
#  'central colo': 10873,
#  'central macdonald': 10874,
#  'central mangrove': 10875,
#  'chain valley bay': 10879,
#  'charmhaven': 10888,
#  'chatswood': 10891,
#  'chatswood west': 10892,
#  'cheero point': 10894,
#  'cheltenham nsw': 10895,
#  'cherrybrook': 10897,
#  'chester hill': 10898,
#  'chifley nsw': 10900,
#  'chippendale': 10906,
#  'chipping norton': 10907,
#  'chiswick': 10909,
#  'chittaway bay': 10910,
#  'chittaway point': 10911,
#  'chullora': 10913,
#  'church point': 10914,
#  'claremont meadows': 10917,
#  'clarendon nsw': 10920,
#  'clareville': 10922,
#  'claymore': 10923,
#  'clemton park': 10927,
#  'clontarf nsw': 10934,
#  'clovelly': 10937,
#  'clyde nsw': 10940,
#  'coasters retreat': 10945,
#  'cobbitty': 10953,
#  'cogra bay': 10961,
#  'colebee': 10965,
#  'collaroy nsw': 10970,
#  'collaroy plateau': 10971,
#  'colo hawkesbury nsw': 10983,
#  'colo heights': 10984,
#  'colongra': 10986,
#  'colyton': 10987,
#  'como nsw': 10996,
#  'concord': 10999,
#  'concord west': 11000,
#  'condell park': 11001,
#  'connells point': 11013,
#  'constitution hill': 11014,
#  'coogee nsw': 11015,
#  'copacabana': 11056,
#  'cornwallis': 11078,
#  'cottage point': 11086,
#  'couridjah': 11093,
#  'cowan': 11097,
#  'cranebrook': 11105,
#  'cremorne nsw': 11113,
#  'cremorne point': 11114,
#  'cromer nsw': 11119,
#  'cronulla': 11120,
#  'crows nest nsw': 11132,
#  'croydon nsw': 11135,
#  'croydon park nsw': 11136,
#  'cumberland reach': 11157,
#  'curl curl': 12998,
#  'currans hill': 11176,
#  'daceyville': 11186,
#  'daleys point': 11190,
#  'dangar island': 11200,
#  'darling point': 11212,
#  'darlinghurst': 11213,
#  'darlington sydney nsw': 11215,
#  'davidson': 11221,
#  'davistown': 11223,
#  'dawes point': 11224,
#  'dean park': 11226,
#  'dee why': 11229,
#  'denham court': 11237,
#  'denistone': 11240,
#  'denistone east': 11241,
#  'denistone west': 11242,
#  'dharruk': 11250,
#  'dolans bay': 11268,
#  'dolls point': 11269,
#  'doonside': 11277,
#  'dooralong': 11278,
#  'double bay': 11283,
#  'douglas park': 11285,
#  'dover heights': 11286,
#  'doyalson': 11288,
#  'doyalson north': 11289,
#  'drummoyne': 11296,
#  'duffys forest': 11304,
#  'dulwich hill': 11306,
#  'dundas nsw': 11315,
#  'dundas valley': 11316,
#  'dural hornsby nsw': 11331,
#  'durren durren': 11339,
#  'eagle vale': 11344,
#  'earlwood': 11346,
#  'east gosford': 11352,
#  'east hills': 11354,
#  'east killara': 11358,
#  'east kurrajong': 11359,
#  'east lindfield': 11360,
#  'east ryde': 11364,
#  'eastern creek': 11369,
#  'eastgardens': 11370,
#  'eastlakes': 11371,
#  'eastwood nsw': 11372,
#  'ebenezer nsw': 11374,
#  'edensor park': 11380,
#  'edgecliff': 11382,
#  'edmondson park': 11386,
#  'elanora heights': 11392,
#  'elderslie camden nsw': 11394,
#  'elizabeth bay': 11398,
#  'elizabeth hills': 11400,
#  'ellis lane': 11408,
#  'elvina bay': 11413,
#  'emerton': 11416,
#  'empire bay': 11418,
#  'emu heights nsw': 11420,
#  'emu plains': 11421,
#  'enfield nsw': 11424,
#  'engadine': 11425,
#  'englorie park': 11426,
#  'enmore inner west nsw': 11428,
#  'epping nsw': 11431,
#  'erina': 11436,
#  'erina heights': 11437,
#  'ermington': 11438,
#  'erskine park': 11441,
#  'erskineville': 11442,
#  'eschol park': 11444,
#  'ettalong beach': 11448,
#  'eveleigh': 11474,
#  'fairfield nsw': 11480,
#  'fairfield east': 11481,
#  'fairfield heights': 11482,
#  'fairfield west': 11483,
#  'fairlight': 11485,
#  'faulconbridge': 11499,
#  'fernances': 11506,
#  'fiddletown': 11516,
#  'five dock': 11533,
#  'forest glen nsw': 11545,
#  'forest lodge': 11549,
#  'forestville nsw': 11551,
#  'forresters beach': 11552,
#  'fountaindale': 11557,
#  'frazer park': 11562,
#  'freemans': 11566,
#  'freemans reach': 11567,
#  'frenchs forest': 11571,
#  'freshwater nsw': 11572,
#  'gables': 11580,
#  'galston': 11586,
#  'georges hall': 11605,
#  'gilead': 11621,
#  'girraween nsw': 11640,
#  'gladesville': 11642,
#  'glebe nsw': 11645,
#  'gledswood hills': 11646,
#  'glen alpine': 11649,
#  'glenbrook': 11660,
#  'glendenning': 11663,
#  'glenfield nsw': 11668,
#  'glenhaven': 11671,
#  'glenmore nsw': 11673,
#  'glenmore park': 11674,
#  'glenning valley': 11676,
#  'glenorie': 11677,
#  'glenwood nsw': 11686,
#  'glenworth valley': 11687,
#  'glossodia': 11688,
#  'gordon nsw': 11724,
#  'gorokan': 11727,
#  'gosford': 11728,
#  'grantham farm': 11743,
#  'granville nsw': 11745,
#  'grasmere': 11746,
#  'grays point': 11750,
#  'great mackerel beach': 11751,
#  'green point central coast nsw': 11760,
#  'green valley nsw': 11762,
#  'greenacre': 11763,
#  'greendale liverpool nsw': 11765,
#  'greenfield park': 11767,
#  'greengrove': 11768,
#  'greenhills beach': 11770,
#  'greenwich': 11776,
#  'gregory hills': 11780,
#  'greystanes': 11787,
#  'grose vale': 11791,
#  'grose wold': 11792,
#  'guildford nsw': 11796,
#  'guildford west': 11797,
#  'gunderman': 11814,
#  'gwandalan': 11831,
#  'gymea': 11833,
#  'gymea bay': 11834,
#  'haberfield': 11835,
#  'halekulani': 11837,
#  'halloran': 11840,
#  'hamlyn terrace': 11850,
#  'hammondville': 11851,
#  'hardys bay': 11859,
#  'harrington park': 11866,
#  'harris park': 11867,
#  'hassall grove': 11873,
#  'hawkesbury heights': 11879,
#  'haymarket': 11884,
#  'hazelbrook': 11888,
#  'heathcote nsw': 11890,
#  'hebersham': 11893,
#  'heckenberg': 11894,
#  'henley': 11898,
#  'higher macdonald': 11908,
#  'hillsdale': 11918,
#  'hinchinbrook nsw': 11922,
#  'hobartville': 11924,
#  'holgate': 11928,
#  'holroyd': 11932,
#  'holsworthy': 11933,
#  'homebush nsw': 11936,
#  'homebush west': 11937,
#  'horningsea park': 11942,
#  'hornsby': 11943,
#  'hornsby heights': 11944,
#  'horsfield bay': 11948,
#  'horsley park': 11950,
#  'hoxton park': 11958,
#  'hunters hill': 11961,
#  'huntingwood': 11964,
#  'huntleys cove': 11967,
#  'huntleys point': 11968,
#  'hurlstone park': 11970,
#  'hurstville': 11971,
#  'hurstville grove': 11972,
#  'illawong': 11982,
#  'ingleburn': 11987,
#  'ingleside': 11988,
#  'jamisontown': 12009,
#  'jannali': 12010,
#  'jilliby': 12036,
#  'jordan springs': 12050,
#  'kanangra': 12064,
#  'kangaroo point nsw': 12068,
#  'kangy angy': 12072,
#  'kanwal': 12075,
#  'kareela': 12081,
#  'kariong': 12082,
#  'katoomba': 12085,
#  'kearns': 12087,
#  'kellyville': 12096,
#  'kellyville ridge': 12097,
#  'kemps creek': 12102,
#  'kensington nsw': 12107,
#  'kenthurst': 12108,
#  'kentlyn': 12109,
#  'kiar': 12128,
#  'killara nsw': 12137,
#  'killarney heights': 12138,
#  'killarney vale': 12139,
#  'killcare': 12141,
#  'killcare heights': 12142,
#  'kincumber': 12149,
#  'kincumber south': 12150,
#  'kingfisher shores': 12154,
#  'kings langley': 12157,
#  'kings park nsw': 12158,
#  'kingsford nsw': 12164,
#  'kingsgrove': 12166,
#  'kingswood penrith nsw': 12171,
#  'kirkham': 12180,
#  'kirrawee': 12181,
#  'kirribilli': 12182,
#  'kogarah': 12190,
#  'kogarah bay': 12191,
#  'koolewong': 12194,
#  'ku-ring-gai chase': 12213,
#  'kulnura': 12214,
#  'kurmond': 12223,
#  'kurnell': 12224,
#  'kurraba point': 12225,
#  'kurrajong': 12226,
#  'kurrajong heights': 12227,
#  'kurrajong hills': 12228,
#  'kyeemagh': 12234,
#  'kyle bay': 12235,
#  'la perouse': 12238,
#  'lake haven': 12255,
#  'lake munmorah': 12262,
#  'lakemba': 12266,
#  'lakesland': 12267,
#  'lalor park': 12270,
#  'lane cove': 12277,
#  'lane cove north': 12276,
#  'lane cove west': 12277,
#  'lansdowne canterbury-bankstown nsw': 12281,
#  'lansvale': 12284,
#  'lapstone': 12285,
#  'laughtondale': 12290,
#  'lavender bay': 12294,
#  'lawson nsw': 12298,
#  'leets vale': 12303,
#  'leichhardt nsw': 12306,
#  'lemon tree': 12309,
#  'len waters estate': 12310,
#  'leonay': 12313,
#  'leppington': 12314,
#  'lethbridge park': 12316,
#  'leumeah': 12317,
#  'leura': 12318,
#  'lewisham nsw': 12322,
#  'liberty grove': 12324,
#  'lidcombe': 12325,
#  'lilli pilli sutherland shire nsw': 12331,
#  'lilyfield': 12334,
#  'linden nsw': 12344,
#  'lindfield': 12348,
#  'linley point': 12350,
#  'lisarow': 12352,
#  'little bay': 12358,
#  'little jilliby': 12363,
#  'little wobby': 12368,
#  'liverpool': 12370,
#  'llandilo': 12372,
#  'loftus': 12380,
#  'londonderry nsw': 12384,
#  'long jetty': 12387,
#  'long point campbelltown nsw': 12390,
#  'longueville': 12394,
#  'lovett bay': 12406,
#  'lower macdonald': 12417,
#  'lower mangrove': 12418,
#  'lower portland': 12421,
#  'lucas heights': 12426,
#  'luddenham': 12428,
#  'lugarno': 12430,
#  'lurnea': 12431,
#  'macmasters beach': 12441,
#  'macquarie fields': 12442,
#  'macquarie links': 12444,
#  'macquarie park': 12446,
#  'magenta nsw': 12450,
#  'maianbar': 12452,
#  'malabar': 12462,
#  'maldon nsw': 12464,
#  'mangrove creek': 12481,
#  'mangrove mountain': 12482,
#  'manly nsw': 12485,
#  'manly vale': 12486,
#  'mannering park': 12487,
#  'maraylya': 12494,
#  'marayong': 12495,
#  'mardi': 12498,
#  'marlow': 12506,
#  'maroota': 12510,
#  'maroubra': 12511,
#  'marrickville': 12514,
#  'marsden park': 12515,
#  'marsfield': 12516,
#  'mascot': 12529,
#  'matcham': 12530,
#  'matraville': 12534,
#  'mays hill': 12548,
#  'mcgraths hill': 12552,
#  'mcmahons point': 12557,
#  'meadowbank nsw': 12560,
#  'medlow bath': 12563,
#  'megalong valley': 12567,
#  'mellong': 12571,
#  'melonba': 12573,
#  'melrose park nsw': 12574,
#  'menai': 12578,
#  'menangle': 12579,
#  'menangle park': 12580,
#  'merrylands': 12599,
#  'merrylands west': 12600,
#  'middle cove': 12613,
#  'middle dural': 12614,
#  'middleton grange': 12618,
#  'miller': 12628,
#  'millers point': 12630,
#  'milperra': 12636,
#  'milsons passage': 12639,
#  'milsons point': 12640,
#  'minchinbury': 12644,
#  'minto': 12653,
#  'minto heights': 12654,
#  'miranda nsw': 12656,
#  'mogo creek': 12673,
#  'mona vale': 12683,
#  'monterey': 12697,
#  'mooney mooney': 12716,
#  'mooney mooney creek': 12716,
#  'moore park': 31905,
#  'moorebank': 12723,
#  'morning bay': 12736,
#  'mortdale': 12739,
#  'mortlake nsw': 12740,
#  'mosman': 12749,
#  'mount annan': 12756,
#  'mount colah': 12761,
#  'mount druitt': 12767,
#  'mount elliot nsw': 12768,
#  'mount hunter': 12776,
#  'mount irvine': 12778,
#  'mount kuring-gai': 12783,
#  'mount lewis': 12785,
#  'mount pritchard': 12796,
#  'mount riverview': 12799,
#  'mount tomah': 12806,
#  'mount vernon': 12807,
#  'mount victoria': 12808,
#  'mount white': 12814,
#  'mount wilson': 12815,
#  'mountain lagoon': 12817,
#  'mowbray park': 12821,
#  'mulgoa': 12825,
#  'mulgrave nsw': 12826,
#  'narara': 12905,
#  'narellan': 12906,
#  'narellan vale': 12907,
#  'naremburn': 12908,
#  'narrabeen': 12911,
#  'narraweena': 12919,
#  'narwee': 12921,
#  'nattai': 12924,
#  'nelson the hills shire nsw': 12931,
#  'neutral bay': 12943,
#  'newington nsw': 12962,
#  'newport nsw': 12965,
#  'newtown nsw': 12969,
#  'niagara park': 12970,
#  'nirimba fields': 12977,
#  'norah head': 12983,
#  'noraville': 12984,
#  'normanhurst': 12986,
#  'north avoca': 12990,
#  'north balgowlah': 12991,
#  'north bondi': 12994,
#  'north curl curl': 12998,
#  'north epping': 13000,
#  'north gosford': 13001,
#  'north kellyville': 13003,
#  'north manly': 13007,
#  'north narrabeen': 13009,
#  'north parramatta': 13011,
#  'north richmond': 13012,
#  'north rocks': 13013,
#  'north ryde': 13015,
#  'north st marys': 13017,
#  'north strathfield': 13019,
#  'north sydney': 13020,
#  'north turramurra': 13023,
#  'north wahroonga': 13025,
#  'north willoughby': 13026,
#  'northbridge nsw': 13032,
#  'northmead': 13033,
#  'northwood nsw': 13034,
#  'norwest': 13036,
#  'oakdale nsw': 13065,
#  'oakhurst nsw': 13069,
#  'oakville': 13071,
#  'oatlands nsw': 13074,
#  'oatley': 13075,
#  'old guildford': 13088,
#  'old toongabbie': 13092,
#  'oran park': 13102,
#  'orangeville': 13105,
#  'orchard hills': 13106,
#  'ourimbah': 13114,
#  'oxford falls': 13117,
#  'oxley park': 13121,
#  'oyster bay': 13123,
#  'paddington nsw': 13126,
#  'padstow': 13131,
#  'padstow heights': 13132,
#  'pagewood': 13136,
#  'palm beach nsw': 13143,
#  'palm grove nsw': 13144,
#  'palmdale nsw': 13145,
#  'panania': 13155,
#  'parklea': 13164,
#  'parramatta': 13167,
#  'patonga': 13171,
#  'peakhurst': 13179,
#  'peakhurst heights': 13180,
#  'pearl beach': 13182,
#  'peats ridge': 13183,
#  'pemulwuy': 13192,
#  'pendle hill': 13193,
#  'pennant hills': 14266,
#  'penrith': 13195,
#  'penshurst nsw': 13197,
#  'perrys crossing': 13200,
#  'petersham': 13202,
#  'pheasants nest': 13203,
#  'phegans bay': 13204,
#  'phillip bay': 13205,
#  'picketts valley': 13210,
#  'picnic point': 13211,
#  'picton nsw': 13212,
#  'pitt town': 13239,
#  'pitt town bottoms': 13239,
#  'pleasure point': 13241,
#  'plumpton nsw': 13242,
#  'point clare': 13243,
#  'point frederick': 13244,
#  'point piper': 13245,
#  'point wolstoncroft': 13246,
#  'port botany': 13255,
#  'port hacking': 13256,
#  'potts hill': 13267,
#  'potts point': 13268,
#  'prairiewood': 13270,
#  'prestons': 13272,
#  'pretty beach central coast nsw': 13273,
#  'prospect nsw': 13278,
#  'punchbowl canterbury-bankstown nsw': 13286,
#  'putney': 13290,
#  'pymble': 13294,
#  'pyrmont': 13297,
#  'quakers hill': 13299,
#  'queens park nsw': 13307,
#  'queenscliff nsw': 13309,
#  'raby': 13316,
#  'ramsgate': 13322,
#  'ramsgate beach': 13323,
#  'randwick': 13325,
#  'ravensdale': 13333,
#  'razorback': 13341,
#  'redfern': 13352,
#  'regents park nsw': 13358,
#  'regentville': 13359,
#  'revesby': 13369,
#  'revesby heights': 13370,
#  'rhodes': 13372,
#  'richards': 13373,
#  'richmond nsw': 13375,
#  'richmond lowlands': 13377,
#  'riverstone': 13383,
#  'riverview nsw': 13385,
#  'riverwood': 13386,
#  'rockdale': 13394,
#  'rocky point nsw': 13403,
#  'rodd point': 13406,
#  'rookwood nsw': 13409,
#  'rooty hill': 13410,
#  'ropes crossing': 13411,
#  'rose bay nsw': 13412,
#  'rosebery nsw': 13419,
#  'rosehill nsw': 13422,
#  'roselands': 13423,
#  'rosemeadow': 13424,
#  'roseville': 13426,
#  'roseville chase': 13427,
#  'rossmore nsw': 13434,
#  'rouse hill': 13444,
#  'royal national park': 13448,
#  'rozelle': 13450,
#  'ruse': 13458,
#  'rushcutters bay': 13459,
#  'russell lea': 13462,
#  'rydalmere': 13468,
#  'ryde': 13469,
#  'sackville': 13473,
#  'sackville north': 13474,
#  'sadleir': 13476,
#  'san remo nsw': 13485,
#  'sandringham nsw': 13493,
#  'sandy point nsw': 13502,
#  'sans souci': 13504,
#  'saratoga': 13507,
#  'scheyville': 13516,
#  'schofields': 13517,
#  'scotland island': 13520,
#  'seaforth nsw': 13524,
#  'sefton': 13531,
#  'seven hills nsw': 13533,
#  'shalvey': 13538,
#  'shanes park': 13539,
#  'shelly beach nsw': 13550,
#  'silverdale nsw': 13559,
#  'silverwater parramatta nsw': 13562,
#  'singletons mill': 13567,
#  'smeaton grange': 13573,
#  'smithfield nsw': 13575,
#  'somersby': 13587,
#  'south coogee': 13595,
#  'south granville': 13599,
#  'south hurstville': 13603,
#  'south maroota': 13608,
#  'south penrith': 13612,
#  'south turramurra': 13614,
#  'south wentworthville': 13615,
#  'south windsor': 13617,
#  'spencer': 13623,
#  'spring farm nsw': 13628,
#  'springfield central coast nsw': 13639,
#  'springwood nsw': 13644,
#  'st albans nsw': 13645,
#  'st andrews nsw': 13646,
#  'st clair penrith nsw': 13647,
#  'st helens park': 13652,
#  'st huberts island': 13653,
#  'st ives nsw': 13654,
#  'st ives chase': 13655,
#  'st johns park': 13656,
#  'st leonards nsw': 13657,
#  'st marys nsw': 13658,
#  'st peters nsw': 13659,
#  'stanhope gardens': 13664,
#  'stanmore nsw': 13665,
#  'strathfield nsw': 13690,
#  'strathfield south': 13691,
#  'summer hill inner west nsw': 13702,
#  'summerland point': 13705,
#  'sun valley nsw': 13706,
#  'surry hills': 13714,
#  'sutherland nsw': 13716,
#  'sydenham nsw': 13729,
#  'sydney': 13730,
#  'sydney olympic park': 13731,
#  'sylvania': 13732,
#  'sylvania waters': 13733,
#  'tacoma': 13739,
#  'tacoma south': 13740,
#  'tahmoor': 13742,
#  'tallawong': 13747,
#  'tamarama': 13757,
#  'taren point': 13781,
#  'tascott': 13787,
#  'telopea': 13797,
#  'tempe': 13800,
#  'ten mile hollow': 13801,
#  'tennyson nsw': 13804,
#  'tennyson point': 13805,
#  'terrey hills': 13819,
#  'terrigal': 13820,
#  'the devils wilderness': 13833,
#  'the entrance': 13835,
#  'the entrance north': 13835,
#  'the oaks': 13847,
#  'the ponds': 13851,
#  'the rocks sydney nsw': 13856,
#  'the slopes': 13858,
#  'theresa park': 13861,
#  'thirlmere': 13863,
#  'thornleigh': 13866,
#  'toongabbie nsw': 13925,
#  'toowoon bay': 13934,
#  'toukley': 13943,
#  'tregear': 13952,
#  'tuggerah': 13968,
#  'tuggerawong': 13969,
#  'tumbi umbi': 13980,
#  'turramurra': 13998,
#  'turrella': 14000,
#  'ultimo': 14024,
#  'umina beach': 14025,
#  'upper colo': 14035,
#  'upper macdonald': 14052,
#  'upper mangrove': 14054,
#  'valley heights': 14087,
#  'varroville': 14088,
#  'vaucluse': 14089,
#  'villawood': 14092,
#  'vineyard': 14094,
#  'voyager point': 14097,
#  'wadalba': 14098,
#  'wagstaffe': 14102,
#  'wahroonga': 14103,
#  'waitara': 14104,
#  'wakeley': 14107,
#  'wallacia': 14119,
#  'wallarah': 14127,
#  'wamberal': 14140,
#  'wareemba': 14166,
#  'warnervale': 14172,
#  'warragamba': 14176,
#  'warrawee': 14183,
#  'warriewood': 14191,
#  'warrimoo': 14192,
#  'warwick farm': 14195,
#  'watanobbi': 14199,
#  'waterfall': 14200,
#  'waterloo nsw': 14201,
#  'watsons bay': 14205,
#  'wattle grove nsw': 14210,
#  'waverley nsw': 14217,
#  'waverton': 14219,
#  'webbs creek': 14225,
#  'wedderburn nsw': 14226,
#  'wendoree park': 14241,
#  'wentworth falls': 14243,
#  'wentworth point': 14244,
#  'wentworthville': 14245,
#  'werombi': 14249,
#  'werrington': 14252,
#  'werrington county': 14253,
#  'werrington downs': 14254,
#  'west gosford': 14261,
#  'west hoxton': 14263,
#  'west pennant hills': 14266,
#  'west pymble': 14267,
#  'west ryde': 14268,
#  'westleigh': 14277,
#  'westmead': 14278,
#  'wetherill park': 14281,
#  'whalan': 14283,
#  'whale beach': 14284,
#  'wheeler heights': 14285,
#  'wheeny creek': 14286,
#  'wilberforce nsw': 14305,
#  'wiley park': 14310,
#  'willmot': 14319,
#  'willoughby nsw': 14320,
#  'willoughby east': 14321,
#  'windsor nsw': 14343,
#  'windsor downs': 14344,
#  'winmalee': 14352,
#  'winston hills': 14353,
#  'wisemans ferry': 14362,
#  'wolli creek': 14371,
#  'wollstonecraft': 14377,
#  'womerah': 14386,
#  'wondabyne': 14389,
#  'woodbine nsw': 14396,
#  'woodcroft nsw': 14399,
#  'woodford nsw': 14401,
#  'woodpark': 14408,
#  'woollahra': 14422,
#  'woolloomooloo': 14424,
#  'woolooware': 14428,
#  'woolwich': 14430,
#  'woongarrah': 14433,
#  'woronora': 14438,
#  'woronora heights': 14440,
#  'woy woy': 14444,
#  'woy woy bay': 14444,
#  'wrights creek nsw': 14447,
#  'wybung': 14455,
#  'wyoming': 14463,
#  'wyong': 14464,
#  'wyong creek': 14465,
#  'wyongah': 14466,
#  'yagoona': 14471,
#  'yanderra': 14479,
#  'yarramalong': 14493,
#  'yarramundi': 14495,
#  'yarrawarrah': 14503,
#  'yattalunga nsw': 14514,
#  'yellow rock blue mountains nsw': 14520,
#  'yennora': 14524,
#  'yerranderie': 14527,
#  'yowie bay': 14537,
#  'zetland': 14542,
#  'aarons pass': 10001,
#  'abercrombie': 10004,
#  'abercrombie river': 10005,
#  'aberdare': 10006,
#  'aberdeen nsw': 10007,
#  'aberfoyle': 10008,
#  'aberglasslyn': 10009,
#  'abermain': 10010,
#  'abernethy': 10011,
#  'abington nsw': 10012,
#  'acacia creek': 12408,
#  'adaminaby': 10015,
#  'adamstown': 10016,
#  'adamstown heights': 10017,
#  'adelong': 10018,
#  'adjungbilly': 10019,
#  'afterlee': 10020,
#  'akolele': 10023,
#  'albert': 10024,
#  'albion park': 10026,
#  'albion park rail': 10026,
#  'albury': 10027,
#  'aldavilla': 10028,
#  'alectown': 10029,
#  'alfredtown': 10032,
#  'alice': 10033,
#  'alison dungog nsw': 10035,
#  'allandale nsw': 10037,
#  'alleena': 10039,
#  'allgomera': 10040,
#  'allworth': 10041,
#  'allynbrook': 10042,
#  'alma park': 10043,
#  'alpine': 10044,
#  'alstonvale': 10045,
#  'alstonville': 10046,
#  'alumy creek': 10047,
#  'amaroo nsw': 10048,
#  'amosfield': 10050,
#  'anabranch north': 10051,
#  'anabranch south': 10052,
#  'anambah': 10053,
#  'ando': 10054,
#  'anembo': 10055,
#  'angledale': 10056,
#  'angledool': 10057,
#  'anglers reach': 10058,
#  'angourie': 10059,
#  'anna bay': 10061,
#  'apple tree flat': 10065,
#  'appleby': 10066,
#  'appletree flat': 10067,
#  'apsley nsw': 10068,
#  'arable': 10069,
#  'arakoon': 10070,
#  'araluen nsw': 10071,
#  'aratula nsw': 10072,
#  'arcadia vale': 10074,
#  'ardglen': 10075,
#  'arding': 10076,
#  'ardlethan': 10077,
#  'argalong': 10078,
#  'argenton': 10079,
#  'argents hill': 10080,
#  'argoon': 10081,
#  'ariah park': 10082,
#  'arkell': 10083,
#  'arkstone': 10084,
#  'armatree': 10085,
#  'armidale': 10086,
#  'arrawarra': 10089,
#  'arrawarra headland': 10090,
#  'arthurville': 10092,
#  'arumpo': 10093,
#  'ashby nsw': 10095,
#  'ashby heights': 10096,
#  'ashby island': 10097,
#  'ashford nsw': 10100,
#  'ashley': 10101,
#  'ashmont': 10102,
#  ...}

# %%
with open(sal_json_path.resolve().parent/'sal.processed.dict.pkl', 'wb') as f:
    pickle.dump(sal_dict, f)
